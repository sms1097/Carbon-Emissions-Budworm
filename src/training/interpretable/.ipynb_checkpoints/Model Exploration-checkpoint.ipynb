# %% [markdown]
# # Version 1.0 Model Predictions

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Import Data Sets
# Here we will import `NetC_Expanded` which is data seperated by management style, result and slavage status, and we will import the predictors and join those datasets.

# %%
netc_expanded = pd.read_csv('../Data/NetC_Expanded.csv')
netc_expanded = netc_expanded.drop(['Unnamed: 0'], axis=1)
netc_expanded.head()
# Out:
#    TimeStep  Risk_Cat                Stand_ID  Salvage Management      Result
# 0         0         4  0023200606030102900043     True      Heavy -249.287884
# 1         0         4  0023200606030102900043     True     NoMgmt -321.931519
# 2         0         4  0023200606030102900043     True   Moderate -276.111511
# 3         0         4  0023200606030102900043     True   Comm-Ind -250.583375
# 4         0         4  0023200606030102900043     True  HighGrade -293.426896

# %%
predictors = pd.read_csv('../Data/Predict_SBW_wCarbon_T0to40.csv')
predictors = predictors.rename(columns={'StandID': 'Stand_ID'})
predictors = predictors.set_index('Stand_ID')
predictors = predictors[["BF_BA","OHost_BA","BF_Stock","OHost_Stock","NonHost_Stock","BF_QMD","ELEV","SLOPE","ASPECT","LAT","SiteInd"]]
predictors.head()
# Out:
#                            BF_BA   OHost_BA  BF_Stock  OHost_Stock  \
# Stand_ID
# 0023200606030200300067       NaN   0.498332       NaN     0.883600
# 0023200606030200300826  3.899610  11.890484   21.8437     0.885569
# 0023200606030200300924  0.036869   7.443510    0.2679     1.166825
# 0023200606030301901813  0.967649   1.368845   63.7216     1.609179
# 0023200606030400901513  3.352901   6.679677   73.4189     1.397641
#
#                         NonHost_Stock    BF_QMD  ELEV  SLOPE  ASPECT  \
# Stand_ID
# 0023200606030200300067        56.9255       NaN   580    5.0   240.0
# 0023200606030200300826        18.6635  4.965398  1170    0.0     0.0
# 0023200606030200300924         3.8019  2.600000   990    0.0     0.0
# 0023200606030301901813        12.1858  2.106063   180    0.0     0.0
# 0023200606030400901513        18.2434  3.405766   250    0.0     0.0
#
#                              LAT  SiteInd
# Stand_ID
# 0023200606030200300067  46.14358      NaN
# 0023200606030200300826  47.19684     28.0
# 0023200606030200300924  46.64171     33.0
# 0023200606030301901813  45.09319     40.0
# 0023200606030400901513  44.73563      NaN

# %% [markdown]
# ## Selecting Management Style
# Gong to define a management style upfront to create rule set

# %%
MANAGEMENT_STYLE = 'NoMgmt'

# %%
mgmt_df = netc_expanded[netc_expanded['Management'] == MANAGEMENT_STYLE]

# %%
x = mgmt_df[(mgmt_df['Stand_ID'] == '0023200606030400901513') & 
            (mgmt_df['TimeStep'] == 40)].groupby('Salvage').head().set_index('Salvage')

# %%
x
# Out:
#          TimeStep  Risk_Cat                Stand_ID Management      Result
# Salvage
# True           40         1  0023200606030400901513     NoMgmt -340.709429
# False          40         1  0023200606030400901513     NoMgmt -286.246874

# %% [markdown]
# Choosing a left join to drop `na` for

# %%
def get_mgmt_df(target_df, pred_df):
    """
    Returns labeled DF for salvage and non salvage decisions
    """
    temp_df = pd.DataFrame(columns=['Stand_ID', 'Salvage_Good', 'Result'])
    for stand in target_df['Stand_ID'].unique():
#         group_df = target_df[
#             target_df['Stand_ID'] == stand
#         ].groupby(['Salvage']).agg({'Result': np.min})

        group_df = target_df[(target_df['Stand_ID'] == stand)
                             & (target_df['TimeStep'] == 40)]
        group_df = group_df.set_index('Salvage')
        
        # If index is True where min is acheived
        if group_df['Result'].idxmin():
            temp_df = temp_df.append(
                pd.DataFrame({
                    'Stand_ID': [stand],
                    'Salvage_Good': [True],
                    'Result': [group_df['Result'].min()]
                })
            )
        else:
            temp_df = temp_df.append(
                pd.DataFrame({
                    'Stand_ID': [stand],
                    'Salvage_Good': [False],
                    'Result': [group_df['Result'].min()]
                })
            )
            
    temp_df = temp_df.set_index('Stand_ID')
    return pd.merge(pred_df, temp_df, on="Stand_ID", right_index=True)

# %%
heavy_df = get_mgmt_df(mgmt_df, predictors)

# %%
heavy_df = heavy_df.dropna()

# %%
heavy_df.head()
# Out:
#                             BF_BA   OHost_BA  BF_Stock  OHost_Stock  \
# Stand_ID
# 0023200606030200300826   3.899610  11.890484   21.8437     0.885569
# 0023200606030200300924   0.036869   7.443510    0.2679     1.166825
# 0023200606030301901813   0.967649   1.368845   63.7216     1.609179
# 0023200606030702501209   2.604667   6.283662   46.1259     1.327920
# 0023200606030702501226  17.937933  19.655671   60.2632     0.808564
#
#                         NonHost_Stock    BF_QMD  ELEV  SLOPE  ASPECT  \
# Stand_ID
# 0023200606030200300826        18.6635  4.965398  1170    0.0     0.0
# 0023200606030200300924         3.8019  2.600000   990    0.0     0.0
# 0023200606030301901813        12.1858  2.106063   180    0.0     0.0
# 0023200606030702501209        37.9627  3.545086  1360    0.0     0.0
# 0023200606030702501226        11.8988  6.622135  1480   25.0   216.0
#
#                              LAT  SiteInd Salvage_Good      Result
# Stand_ID
# 0023200606030200300826  47.19684     28.0         True -378.709805
# 0023200606030200300924  46.64171     33.0         True -384.995331
# 0023200606030301901813  45.09319     40.0         True -537.624581
# 0023200606030702501209  46.33241     31.0         True -261.114995
# 0023200606030702501226  45.69559     38.0        False -258.286555

# %%
heavy_df['Salvage_Good'].value_counts()
# Out:
# True     3538
# False     699
# Name: Salvage_Good, dtype: int64

# %% [markdown]
# Here we can see that the option to not salvage benefited more than salvaging, so in this case we won't offer salvage credit.

# %% [markdown]
# ## Split Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
heavy_df = heavy_df.reset_index().drop('Stand_ID', axis=1)

# %%
X = heavy_df.drop(['Salvage_Good', 'Result'], axis=1)
y = heavy_df[['Salvage_Good']].astype('int')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Decision Tree
# Going to explore what the upper bound is for classification error on this data set.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import _tree

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8077830188679245

# %%
accuracy_score(y_train, clf.predict(X_train))
# Out:
# 1.0

# %%
y.value_counts() / len(y)
# Out:
# Salvage_Good
# 1               0.835025
# 0               0.164975
# dtype: float64

# %%
def tree_to_code(tree, feature_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    print("def tree({}):".format(", ".join(feature_names)))

    def recurse(node, depth):
        indent = "  " * depth
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            print("{}if {} <= {}:".format(indent, name, threshold))
            recurse(tree_.children_left[node], depth + 1)
            print ("{}else:  # if {} > {}".format(indent, name, threshold))
            recurse(tree_.children_right[node], depth + 1)
        else:
            print ("{}return {}".format(indent, tree_.value[node]))

    recurse(0, 1)

tree_to_code(clf, X_train.columns)
# Out:
# def tree(BF_BA, OHost_BA, BF_Stock, OHost_Stock, NonHost_Stock, BF_QMD, ELEV, SLOPE, ASPECT, LAT, SiteInd):
#   if BF_QMD <= 6.892452955245972:
#     if BF_Stock <= 2.941999912261963:
#       if OHost_Stock <= 0.44407157599925995:
#         if BF_QMD <= 6.4006288051605225:
#           if BF_BA <= 0.019252620171755552:
#             return [[1. 0.]]
#           else:  # if BF_BA > 0.019252620171755552
#             if NonHost_Stock <= 44.36865043640137:
#               if NonHost_Stock <= 43.633501052856445:
#                 if ASPECT <= 230.5:
#                   return [[ 0. 13.]]
#                 else:  # if ASPECT > 230.5
#                   return [[1. 0.]]
#               else:  # if NonHost_Stock > 43.633501052856445
#                 return [[2. 0.]]
#             else:  # if NonHost_Stock > 44.36865043640137
#               if OHost_BA <= 0.18489060178399086:
#                 if BF_QMD <= 1.797840178012848:
#                   return [[0. 1.]]
#                 else:  # if BF_QMD > 1.797840178012848
#                   return [[1. 0.]]
#               else:  # if OHost_BA > 0.18489060178399086
#                 return [[ 0. 64.]]
#         else:  # if BF_QMD > 6.4006288051605225
#           if OHost_BA <= 1.7891846895217896:
#             return [[2. 0.]]
#           else:  # if OHost_BA > 1.7891846895217896
#             if SLOPE <= 2.5:
#               return [[1. 0.]]
#             else:  # if SLOPE > 2.5
#               return [[0. 3.]]
#       else:  # if OHost_Stock > 0.44407157599925995
#         if BF_Stock <= 0.46594999730587006:
#           if BF_Stock <= 0.3384999930858612:
#             if OHost_BA <= 14.9079909324646:
#               if BF_QMD <= 1.449999988079071:
#                 if NonHost_Stock <= 30.799299716949463:
#                   return [[0. 1.]]
#                 else:  # if NonHost_Stock > 30.799299716949463
#                   return [[4. 0.]]
#               else:  # if BF_QMD > 1.449999988079071
#                 if SiteInd <= 57.5:
#                   if LAT <= 43.46075439453125:
#                     return [[1. 0.]]
#                   else:  # if LAT > 43.46075439453125
#                     return [[ 0. 19.]]
#                 else:  # if SiteInd > 57.5
#                   return [[2. 0.]]
#             else:  # if OHost_BA > 14.9079909324646
#               if BF_QMD <= 1.1500000357627869:
#                 return [[0. 1.]]
#               else:  # if BF_QMD > 1.1500000357627869
#                 return [[7. 0.]]
#           else:  # if BF_Stock > 0.3384999930858612
#             if NonHost_Stock <= 9.814949750900269:
#               return [[0. 1.]]
#             else:  # if NonHost_Stock > 9.814949750900269
#               return [[11.  0.]]
#         else:  # if BF_Stock > 0.46594999730587006
#           if SiteInd <= 34.5:
#             if ELEV <= 385.0:
#               if LAT <= 44.50635528564453:
#                 return [[2. 0.]]
#               else:  # if LAT > 44.50635528564453
#                 if BF_Stock <= 2.2489500045776367:
#                   return [[ 0. 14.]]
#                 else:  # if BF_Stock > 2.2489500045776367
#                   if OHost_BA <= 2.901146322488785:
#                     return [[0. 1.]]
#                   else:  # if OHost_BA > 2.901146322488785
#                     return [[2. 0.]]
#             else:  # if ELEV > 385.0
#               if ELEV <= 1060.0:
#                 if NonHost_Stock <= 61.803401947021484:
#                   if OHost_BA <= 19.461344718933105:
#                     if LAT <= 46.75702095031738:
#                       return [[17.  0.]]
#                     else:  # if LAT > 46.75702095031738
#                       if BF_Stock <= 2.688599944114685:
#                         return [[0. 1.]]
#                       else:  # if BF_Stock > 2.688599944114685
#                         return [[1. 0.]]
#                   else:  # if OHost_BA > 19.461344718933105
#                     return [[0. 1.]]
#                 else:  # if NonHost_Stock > 61.803401947021484
#                   return [[0. 1.]]
#               else:  # if ELEV > 1060.0
#                 if ASPECT <= 282.5:
#                   if OHost_BA <= 13.186844825744629:
#                     if NonHost_Stock <= 51.89790153503418:
#                       return [[0. 9.]]
#                     else:  # if NonHost_Stock > 51.89790153503418
#                       if OHost_BA <= 4.394969463348389:
#                         return [[1. 0.]]
#                       else:  # if OHost_BA > 4.394969463348389
#                         return [[0. 2.]]
#                   else:  # if OHost_BA > 13.186844825744629
#                     return [[2. 0.]]
#                 else:  # if ASPECT > 282.5
#                   return [[3. 0.]]
#           else:  # if SiteInd > 34.5
#             if BF_QMD <= 4.5372068881988525:
#               if BF_BA <= 0.01878902968019247:
#                 if ELEV <= 575.0:
#                   return [[0. 2.]]
#                 else:  # if ELEV > 575.0
#                   return [[3. 0.]]
#               else:  # if BF_BA > 0.01878902968019247
#                 if ELEV <= 1060.0:
#                   return [[ 0. 46.]]
#                 else:  # if ELEV > 1060.0
#                   if BF_QMD <= 4.086233377456665:
#                     if BF_QMD <= 3.513727068901062:
#                       return [[ 0. 14.]]
#                     else:  # if BF_QMD > 3.513727068901062
#                       if BF_QMD <= 3.6149868965148926:
#                         return [[1. 0.]]
#                       else:  # if BF_QMD > 3.6149868965148926
#                         return [[0. 5.]]
#                   else:  # if BF_QMD > 4.086233377456665
#                     if BF_QMD <= 4.160266637802124:
#                       return [[2. 0.]]
#                     else:  # if BF_QMD > 4.160266637802124
#                       return [[0. 3.]]
#             else:  # if BF_QMD > 4.5372068881988525
#               if BF_BA <= 0.4659624993801117:
#                 if SiteInd <= 58.0:
#                   if NonHost_Stock <= 85.70069885253906:
#                     if ELEV <= 105.0:
#                       return [[0. 1.]]
#                     else:  # if ELEV > 105.0
#                       return [[11.  0.]]
#                   else:  # if NonHost_Stock > 85.70069885253906
#                     return [[0. 1.]]
#                 else:  # if SiteInd > 58.0
#                   if BF_Stock <= 1.083899974822998:
#                     if ELEV <= 515.0:
#                       return [[1. 0.]]
#                     else:  # if ELEV > 515.0
#                       return [[0. 1.]]
#                   else:  # if BF_Stock > 1.083899974822998
#                     return [[0. 3.]]
#               else:  # if BF_BA > 0.4659624993801117
#                 if NonHost_Stock <= 30.85080051422119:
#                   if OHost_Stock <= 1.0863579511642456:
#                     if ELEV <= 135.0:
#                       return [[0. 3.]]
#                     else:  # if ELEV > 135.0
#                       if OHost_BA <= 1.2853441834449768:
#                         return [[0. 2.]]
#                       else:  # if OHost_BA > 1.2853441834449768
#                         if BF_QMD <= 5.429350137710571:
#                           if BF_Stock <= 2.0825999975204468:
#                             return [[2. 0.]]
#                           else:  # if BF_Stock > 2.0825999975204468
#                             return [[0. 2.]]
#                         else:  # if BF_QMD > 5.429350137710571
#                           return [[10.  0.]]
#                   else:  # if OHost_Stock > 1.0863579511642456
#                     if BF_Stock <= 2.3605499267578125:
#                       return [[0. 9.]]
#                     else:  # if BF_Stock > 2.3605499267578125
#                       if BF_Stock <= 2.9120500087738037:
#                         return [[2. 0.]]
#                       else:  # if BF_Stock > 2.9120500087738037
#                         return [[0. 1.]]
#                 else:  # if NonHost_Stock > 30.85080051422119
#                   if SiteInd <= 37.5:
#                     if NonHost_Stock <= 40.08625030517578:
#                       return [[0. 3.]]
#                     else:  # if NonHost_Stock > 40.08625030517578
#                       if ELEV <= 640.0:
#                         return [[4. 0.]]
#                       else:  # if ELEV > 640.0
#                         if OHost_BA <= 5.290543556213379:
#                           return [[2. 0.]]
#                         else:  # if OHost_BA > 5.290543556213379
#                           return [[0. 3.]]
#                   else:  # if SiteInd > 37.5
#                     if BF_QMD <= 6.442588806152344:
#                       if BF_BA <= 0.6322822272777557:
#                         if ASPECT <= 130.0:
#                           return [[3. 0.]]
#                         else:  # if ASPECT > 130.0
#                           return [[0. 3.]]
#                       else:  # if BF_BA > 0.6322822272777557
#                         if LAT <= 43.93146324157715:
#                           if OHost_Stock <= 1.2859808206558228:
#                             return [[1. 0.]]
#                           else:  # if OHost_Stock > 1.2859808206558228
#                             return [[0. 2.]]
#                         else:  # if LAT > 43.93146324157715
#                           if OHost_BA <= 1.9665488004684448:
#                             if LAT <= 44.854671478271484:
#                               return [[1. 0.]]
#                             else:  # if LAT > 44.854671478271484
#                               return [[0. 5.]]
#                           else:  # if OHost_BA > 1.9665488004684448
#                             return [[ 0. 36.]]
#                     else:  # if BF_QMD > 6.442588806152344
#                       if BF_BA <= 1.3693630695343018:
#                         if BF_Stock <= 1.2140499949455261:
#                           return [[1. 0.]]
#                         else:  # if BF_Stock > 1.2140499949455261
#                           return [[0. 5.]]
#                       else:  # if BF_BA > 1.3693630695343018
#                         return [[4. 0.]]
#     else:  # if BF_Stock > 2.941999912261963
#       if BF_Stock <= 14.898550033569336:
#         if OHost_Stock <= 1.1135083436965942:
#           if SiteInd <= 21.5:
#             return [[2. 0.]]
#           else:  # if SiteInd > 21.5
#             if NonHost_Stock <= 20.104450225830078:
#               if OHost_BA <= 4.94961404800415:
#                 if OHost_Stock <= 0.9255273640155792:
#                   if LAT <= 44.81601905822754:
#                     return [[3. 0.]]
#                   else:  # if LAT > 44.81601905822754
#                     if SiteInd <= 30.5:
#                       return [[1. 0.]]
#                     else:  # if SiteInd > 30.5
#                       return [[ 0. 10.]]
#                 else:  # if OHost_Stock > 0.9255273640155792
#                   if SiteInd <= 29.5:
#                     return [[0. 1.]]
#                   else:  # if SiteInd > 29.5
#                     return [[6. 0.]]
#               else:  # if OHost_BA > 4.94961404800415
#                 if LAT <= 44.544437408447266:
#                   if OHost_BA <= 11.156020641326904:
#                     return [[0. 6.]]
#                   else:  # if OHost_BA > 11.156020641326904
#                     if LAT <= 43.692378997802734:
#                       return [[0. 2.]]
#                     else:  # if LAT > 43.692378997802734
#                       if OHost_Stock <= 0.8133051693439484:
#                         if OHost_BA <= 14.76915979385376:
#                           return [[1. 0.]]
#                         else:  # if OHost_BA > 14.76915979385376
#                           return [[0. 2.]]
#                       else:  # if OHost_Stock > 0.8133051693439484
#                         return [[6. 0.]]
#                 else:  # if LAT > 44.544437408447266
#                   if BF_Stock <= 14.808799743652344:
#                     if BF_Stock <= 3.444300055503845:
#                       if SiteInd <= 41.5:
#                         return [[0. 2.]]
#                       else:  # if SiteInd > 41.5
#                         return [[1. 0.]]
#                     else:  # if BF_Stock > 3.444300055503845
#                       return [[ 0. 53.]]
#                   else:  # if BF_Stock > 14.808799743652344
#                     return [[1. 0.]]
#             else:  # if NonHost_Stock > 20.104450225830078
#               if OHost_BA <= 17.853232383728027:
#                 if LAT <= 45.74814033508301:
#                   if LAT <= 44.54256248474121:
#                     if OHost_BA <= 3.9566588401794434:
#                       if ELEV <= 1270.0:
#                         if BF_BA <= 3.849242329597473:
#                           if LAT <= 44.52309226989746:
#                             return [[ 0. 35.]]
#                           else:  # if LAT > 44.52309226989746
#                             return [[1. 0.]]
#                         else:  # if BF_BA > 3.849242329597473
#                           return [[2. 0.]]
#                       else:  # if ELEV > 1270.0
#                         if BF_BA <= 1.9391970038414001:
#                           if SiteInd <= 56.5:
#                             if OHost_BA <= 1.4677532315254211:
#                               return [[3. 0.]]
#                             else:  # if OHost_BA > 1.4677532315254211
#                               if NonHost_Stock <= 60.14755058288574:
#                                 if SLOPE <= 10.5:
#                                   return [[0. 1.]]
#                                 else:  # if SLOPE > 10.5
#                                   return [[2. 0.]]
#                               else:  # if NonHost_Stock > 60.14755058288574
#                                 return [[0. 3.]]
#                           else:  # if SiteInd > 56.5
#                             return [[0. 6.]]
#                         else:  # if BF_BA > 1.9391970038414001
#                           return [[4. 0.]]
#                     else:  # if OHost_BA > 3.9566588401794434
#                       if LAT <= 44.50320625305176:
#                         if BF_BA <= 8.773195266723633:
#                           if LAT <= 44.48646545410156:
#                             return [[  0. 102.]]
#                           else:  # if LAT > 44.48646545410156
#                             if OHost_Stock <= 0.4478461891412735:
#                               return [[1. 0.]]
#                             else:  # if OHost_Stock > 0.4478461891412735
#                               return [[0. 5.]]
#                         else:  # if BF_BA > 8.773195266723633
#                           if OHost_Stock <= 0.6610863953828812:
#                             return [[0. 1.]]
#                           else:  # if OHost_Stock > 0.6610863953828812
#                             return [[1. 0.]]
#                       else:  # if LAT > 44.50320625305176
#                         if OHost_BA <= 6.205915689468384:
#                           return [[0. 1.]]
#                         else:  # if OHost_BA > 6.205915689468384
#                           return [[1. 0.]]
#                   else:  # if LAT > 44.54256248474121
#                     if OHost_BA <= 14.986364841461182:
#                       if OHost_BA <= 2.286889433860779:
#                         if OHost_BA <= 2.2479206323623657:
#                           if BF_QMD <= 5.776466608047485:
#                             return [[ 0. 73.]]
#                           else:  # if BF_QMD > 5.776466608047485
#                             if SLOPE <= 3.5:
#                               return [[2. 0.]]
#                             else:  # if SLOPE > 3.5
#                               return [[0. 4.]]
#                         else:  # if OHost_BA > 2.2479206323623657
#                           return [[1. 0.]]
#                       else:  # if OHost_BA > 2.286889433860779
#                         if NonHost_Stock <= 28.96125030517578:
#                           if NonHost_Stock <= 28.813400268554688:
#                             return [[ 0. 27.]]
#                           else:  # if NonHost_Stock > 28.813400268554688
#                             return [[1. 0.]]
#                         else:  # if NonHost_Stock > 28.96125030517578
#                           return [[  0. 237.]]
#                     else:  # if OHost_BA > 14.986364841461182
#                       if OHost_BA <= 15.06013011932373:
#                         return [[1. 0.]]
#                       else:  # if OHost_BA > 15.06013011932373
#                         return [[0. 5.]]
#                 else:  # if LAT > 45.74814033508301
#                   if LAT <= 45.770755767822266:
#                     if BF_QMD <= 3.9190938472747803:
#                       return [[0. 1.]]
#                     else:  # if BF_QMD > 3.9190938472747803
#                       return [[3. 0.]]
#                   else:  # if LAT > 45.770755767822266
#                     if BF_QMD <= 6.566412925720215:
#                       if SiteInd <= 40.5:
#                         if BF_QMD <= 5.083899259567261:
#                           if OHost_BA <= 0.34782885015010834:
#                             if BF_QMD <= 2.2993528842926025:
#                               return [[0. 1.]]
#                             else:  # if BF_QMD > 2.2993528842926025
#                               return [[1. 0.]]
#                           else:  # if OHost_BA > 0.34782885015010834
#                             if LAT <= 45.80924034118652:
#                               if SLOPE <= 2.5:
#                                 return [[0. 1.]]
#                               else:  # if SLOPE > 2.5
#                                 return [[1. 0.]]
#                             else:  # if LAT > 45.80924034118652
#                               return [[ 0. 38.]]
#                         else:  # if BF_QMD > 5.083899259567261
#                           if BF_BA <= 1.600476324558258:
#                             return [[3. 0.]]
#                           else:  # if BF_BA > 1.600476324558258
#                             if NonHost_Stock <= 71.26029968261719:
#                               if BF_QMD <= 5.137369871139526:
#                                 return [[1. 0.]]
#                               else:  # if BF_QMD > 5.137369871139526
#                                 if OHost_BA <= 2.783967137336731:
#                                   if ASPECT <= 28.0:
#                                     return [[0. 2.]]
#                                   else:  # if ASPECT > 28.0
#                                     return [[1. 0.]]
#                                 else:  # if OHost_BA > 2.783967137336731
#                                   return [[ 0. 25.]]
#                             else:  # if NonHost_Stock > 71.26029968261719
#                               if OHost_BA <= 5.382197856903076:
#                                 if NonHost_Stock <= 74.14080047607422:
#                                   return [[1. 0.]]
#                                 else:  # if NonHost_Stock > 74.14080047607422
#                                   return [[0. 4.]]
#                               else:  # if OHost_BA > 5.382197856903076
#                                 return [[4. 0.]]
#                       else:  # if SiteInd > 40.5
#                         if ELEV <= 1395.0:
#                           return [[ 0. 75.]]
#                         else:  # if ELEV > 1395.0
#                           if ELEV <= 1460.0:
#                             return [[1. 0.]]
#                           else:  # if ELEV > 1460.0
#                             return [[0. 5.]]
#                     else:  # if BF_QMD > 6.566412925720215
#                       if BF_Stock <= 8.480999946594238:
#                         if SiteInd <= 37.5:
#                           if SiteInd <= 31.0:
#                             return [[1. 0.]]
#                           else:  # if SiteInd > 31.0
#                             return [[0. 2.]]
#                         else:  # if SiteInd > 37.5
#                           return [[4. 0.]]
#                       else:  # if BF_Stock > 8.480999946594238
#                         return [[0. 5.]]
#               else:  # if OHost_BA > 17.853232383728027
#                 return [[2. 0.]]
#         else:  # if OHost_Stock > 1.1135083436965942
#           if SiteInd <= 29.75:
#             if OHost_Stock <= 2.8204827308654785:
#               if OHost_Stock <= 1.3299872279167175:
#                 if SLOPE <= 2.5:
#                   return [[0. 2.]]
#                 else:  # if SLOPE > 2.5
#                   return [[1. 0.]]
#               else:  # if OHost_Stock > 1.3299872279167175
#                 return [[7. 0.]]
#             else:  # if OHost_Stock > 2.8204827308654785
#               return [[0. 4.]]
#           else:  # if SiteInd > 29.75
#             if NonHost_Stock <= 25.745049476623535:
#               if OHost_BA <= 3.1461398601531982:
#                 if OHost_Stock <= 1.3061714172363281:
#                   if BF_Stock <= 9.464449882507324:
#                     return [[2. 0.]]
#                   else:  # if BF_Stock > 9.464449882507324
#                     return [[0. 1.]]
#                 else:  # if OHost_Stock > 1.3061714172363281
#                   if LAT <= 43.234954833984375:
#                     return [[1. 0.]]
#                   else:  # if LAT > 43.234954833984375
#                     if LAT <= 44.58638954162598:
#                       if BF_BA <= 0.34924689680337906:
#                         return [[1. 0.]]
#                       else:  # if BF_BA > 0.34924689680337906
#                         return [[0. 5.]]
#                     else:  # if LAT > 44.58638954162598
#                       return [[ 0. 21.]]
#               else:  # if OHost_BA > 3.1461398601531982
#                 if ELEV <= 530.0:
#                   if ELEV <= 210.0:
#                     return [[0. 1.]]
#                   else:  # if ELEV > 210.0
#                     return [[10.  0.]]
#                 else:  # if ELEV > 530.0
#                   if ELEV <= 1275.0:
#                     return [[0. 8.]]
#                   else:  # if ELEV > 1275.0
#                     if OHost_BA <= 16.12382411956787:
#                       return [[4. 0.]]
#                     else:  # if OHost_BA > 16.12382411956787
#                       return [[0. 3.]]
#             else:  # if NonHost_Stock > 25.745049476623535
#               if OHost_Stock <= 4.420858383178711:
#                 if OHost_Stock <= 1.1173295378684998:
#                   return [[1. 0.]]
#                 else:  # if OHost_Stock > 1.1173295378684998
#                   if BF_Stock <= 3.8109500408172607:
#                     if BF_QMD <= 4.041060090065002:
#                       return [[0. 4.]]
#                     else:  # if BF_QMD > 4.041060090065002
#                       return [[3. 0.]]
#                   else:  # if BF_Stock > 3.8109500408172607
#                     if SiteInd <= 52.5:
#                       if OHost_BA <= 1.6589977741241455:
#                         if SLOPE <= 12.5:
#                           if BF_QMD <= 4.601943492889404:
#                             return [[ 0. 15.]]
#                           else:  # if BF_QMD > 4.601943492889404
#                             if BF_QMD <= 5.254213571548462:
#                               if ASPECT <= 193.5:
#                                 return [[4. 0.]]
#                               else:  # if ASPECT > 193.5
#                                 return [[0. 1.]]
#                             else:  # if BF_QMD > 5.254213571548462
#                               if ELEV <= 1375.0:
#                                 return [[0. 8.]]
#                               else:  # if ELEV > 1375.0
#                                 return [[2. 0.]]
#                         else:  # if SLOPE > 12.5
#                           return [[2. 0.]]
#                       else:  # if OHost_BA > 1.6589977741241455
#                         if BF_Stock <= 12.825249671936035:
#                           if BF_QMD <= 6.826647520065308:
#                             if LAT <= 46.88186073303223:
#                               if BF_QMD <= 6.511960983276367:
#                                 if NonHost_Stock <= 115.08205032348633:
#                                   return [[ 0. 52.]]
#                                 else:  # if NonHost_Stock > 115.08205032348633
#                                   if LAT <= 46.095008850097656:
#                                     return [[0. 5.]]
#                                   else:  # if LAT > 46.095008850097656
#                                     return [[1. 0.]]
#                               else:  # if BF_QMD > 6.511960983276367
#                                 if NonHost_Stock <= 61.17035102844238:
#                                   return [[1. 0.]]
#                                 else:  # if NonHost_Stock > 61.17035102844238
#                                   return [[0. 3.]]
#                             else:  # if LAT > 46.88186073303223
#                               if BF_Stock <= 8.534600019454956:
#                                 return [[0. 1.]]
#                               else:  # if BF_Stock > 8.534600019454956
#                                 return [[1. 0.]]
#                           else:  # if BF_QMD > 6.826647520065308
#                             return [[1. 0.]]
#                         else:  # if BF_Stock > 12.825249671936035
#                           if BF_Stock <= 13.008699893951416:
#                             return [[2. 0.]]
#                           else:  # if BF_Stock > 13.008699893951416
#                             if LAT <= 45.008033752441406:
#                               if BF_Stock <= 13.98140001296997:
#                                 return [[3. 0.]]
#                               else:  # if BF_Stock > 13.98140001296997
#                                 return [[0. 3.]]
#                             else:  # if LAT > 45.008033752441406
#                               return [[ 0. 14.]]
#                     else:  # if SiteInd > 52.5
#                       return [[ 0. 36.]]
#               else:  # if OHost_Stock > 4.420858383178711
#                 if BF_BA <= 0.8522420227527618:
#                   if ASPECT <= 113.0:
#                     return [[4. 0.]]
#                   else:  # if ASPECT > 113.0
#                     if OHost_Stock <= 6.049900054931641:
#                       return [[0. 2.]]
#                     else:  # if OHost_Stock > 6.049900054931641
#                       return [[1. 0.]]
#                 else:  # if BF_BA > 0.8522420227527618
#                   return [[0. 3.]]
#       else:  # if BF_Stock > 14.898550033569336
#         if SLOPE <= 72.5:
#           if LAT <= 42.90498924255371:
#             return [[1. 0.]]
#           else:  # if LAT > 42.90498924255371
#             if BF_QMD <= 6.321476936340332:
#               if OHost_Stock <= 1.8919996619224548:
#                 if NonHost_Stock <= 173.84294891357422:
#                   if ASPECT <= 332.5:
#                     if BF_Stock <= 87.13675308227539:
#                       if NonHost_Stock <= 143.60489654541016:
#                         if OHost_BA <= 19.060038566589355:
#                           if LAT <= 46.92276573181152:
#                             if BF_Stock <= 18.66790008544922:
#                               if BF_Stock <= 18.64919948577881:
#                                 return [[  0. 102.]]
#                               else:  # if BF_Stock > 18.64919948577881
#                                 return [[1. 0.]]
#                             else:  # if BF_Stock > 18.66790008544922
#                               return [[  0. 597.]]
#                           else:  # if LAT > 46.92276573181152
#                             if LAT <= 46.924482345581055:
#                               return [[1. 0.]]
#                             else:  # if LAT > 46.924482345581055
#                               return [[ 0. 48.]]
#                         else:  # if OHost_BA > 19.060038566589355
#                           if BF_QMD <= 4.650169610977173:
#                             return [[1. 0.]]
#                           else:  # if BF_QMD > 4.650169610977173
#                             return [[ 0. 12.]]
#                       else:  # if NonHost_Stock > 143.60489654541016
#                         if LAT <= 46.911434173583984:
#                           return [[ 0. 10.]]
#                         else:  # if LAT > 46.911434173583984
#                           return [[1. 0.]]
#                     else:  # if BF_Stock > 87.13675308227539
#                       if BF_Stock <= 89.87055206298828:
#                         return [[1. 0.]]
#                       else:  # if BF_Stock > 89.87055206298828
#                         return [[0. 4.]]
#                   else:  # if ASPECT > 332.5
#                     if BF_Stock <= 15.40245008468628:
#                       return [[1. 0.]]
#                     else:  # if BF_Stock > 15.40245008468628
#                       if BF_QMD <= 6.047733306884766:
#                         if SLOPE <= 43.0:
#                           return [[ 0. 18.]]
#                         else:  # if SLOPE > 43.0
#                           if OHost_Stock <= 0.7298380136489868:
#                             return [[1. 0.]]
#                           else:  # if OHost_Stock > 0.7298380136489868
#                             return [[0. 1.]]
#                       else:  # if BF_QMD > 6.047733306884766
#                         return [[1. 0.]]
#                 else:  # if NonHost_Stock > 173.84294891357422
#                   if OHost_Stock <= 1.57635498046875:
#                     return [[1. 0.]]
#                   else:  # if OHost_Stock > 1.57635498046875
#                     return [[0. 1.]]
#               else:  # if OHost_Stock > 1.8919996619224548
#                 if ELEV <= 1675.0:
#                   if NonHost_Stock <= 122.87790298461914:
#                     if SLOPE <= 7.25:
#                       if SiteInd <= 57.5:
#                         if OHost_BA <= 14.73046350479126:
#                           if LAT <= 44.47385787963867:
#                             if BF_QMD <= 5.660585880279541:
#                               return [[0. 4.]]
#                             else:  # if BF_QMD > 5.660585880279541
#                               return [[1. 0.]]
#                           else:  # if LAT > 44.47385787963867
#                             if BF_QMD <= 4.504125118255615:
#                               return [[  0. 123.]]
#                             else:  # if BF_QMD > 4.504125118255615
#                               if BF_QMD <= 4.518099546432495:
#                                 return [[1. 0.]]
#                               else:  # if BF_QMD > 4.518099546432495
#                                 if NonHost_Stock <= 5.04830002784729:
#                                   if BF_Stock <= 28.71695041656494:
#                                     return [[1. 0.]]
#                                   else:  # if BF_Stock > 28.71695041656494
#                                     return [[0. 4.]]
#                                 else:  # if NonHost_Stock > 5.04830002784729
#                                   return [[ 0. 44.]]
#                         else:  # if OHost_BA > 14.73046350479126
#                           if OHost_BA <= 15.767459392547607:
#                             return [[1. 0.]]
#                           else:  # if OHost_BA > 15.767459392547607
#                             return [[0. 4.]]
#                       else:  # if SiteInd > 57.5
#                         if SLOPE <= 1.5:
#                           return [[0. 3.]]
#                         else:  # if SLOPE > 1.5
#                           return [[1. 0.]]
#                     else:  # if SLOPE > 7.25
#                       if LAT <= 45.96944618225098:
#                         return [[ 0. 28.]]
#                       else:  # if LAT > 45.96944618225098
#                         if BF_Stock <= 63.58859825134277:
#                           if NonHost_Stock <= 73.55915069580078:
#                             if BF_Stock <= 40.630449295043945:
#                               if OHost_BA <= 8.391387939453125:
#                                 return [[0. 3.]]
#                               else:  # if OHost_BA > 8.391387939453125
#                                 return [[2. 0.]]
#                             else:  # if BF_Stock > 40.630449295043945
#                               return [[3. 0.]]
#                           else:  # if NonHost_Stock > 73.55915069580078
#                             return [[0. 3.]]
#                         else:  # if BF_Stock > 63.58859825134277
#                           return [[0. 5.]]
#                   else:  # if NonHost_Stock > 122.87790298461914
#                     if LAT <= 46.809431076049805:
#                       if OHost_Stock <= 5.7772979736328125:
#                         return [[ 0. 10.]]
#                       else:  # if OHost_Stock > 5.7772979736328125
#                         return [[1. 0.]]
#                     else:  # if LAT > 46.809431076049805
#                       return [[2. 0.]]
#                 else:  # if ELEV > 1675.0
#                   if SiteInd <= 46.5:
#                     if BF_BA <= 0.412349671125412:
#                       return [[1. 0.]]
#                     else:  # if BF_BA > 0.412349671125412
#                       if OHost_Stock <= 1.9928796887397766:
#                         return [[1. 0.]]
#                       else:  # if OHost_Stock > 1.9928796887397766
#                         return [[ 0. 16.]]
#                   else:  # if SiteInd > 46.5
#                     return [[4. 0.]]
#             else:  # if BF_QMD > 6.321476936340332
#               if BF_QMD <= 6.329056024551392:
#                 return [[2. 0.]]
#               else:  # if BF_QMD > 6.329056024551392
#                 if BF_BA <= 3.624782919883728:
#                   if LAT <= 46.673715591430664:
#                     if SiteInd <= 51.75:
#                       return [[0. 9.]]
#                     else:  # if SiteInd > 51.75
#                       if BF_BA <= 1.7283453345298767:
#                         return [[0. 1.]]
#                       else:  # if BF_BA > 1.7283453345298767
#                         return [[2. 0.]]
#                   else:  # if LAT > 46.673715591430664
#                     return [[3. 0.]]
#                 else:  # if BF_BA > 3.624782919883728
#                   if SiteInd <= 40.5:
#                     if NonHost_Stock <= 34.357500076293945:
#                       if ELEV <= 1520.0:
#                         if ELEV <= 1400.0:
#                           if LAT <= 45.2448844909668:
#                             if SLOPE <= 5.5:
#                               if BF_Stock <= 24.920499801635742:
#                                 return [[0. 2.]]
#                               else:  # if BF_Stock > 24.920499801635742
#                                 return [[1. 0.]]
#                             else:  # if SLOPE > 5.5
#                               return [[3. 0.]]
#                           else:  # if LAT > 45.2448844909668
#                             return [[0. 7.]]
#                         else:  # if ELEV > 1400.0
#                           return [[3. 0.]]
#                       else:  # if ELEV > 1520.0
#                         return [[ 0. 17.]]
#                     else:  # if NonHost_Stock > 34.357500076293945
#                       return [[ 0. 28.]]
#                   else:  # if SiteInd > 40.5
#                     return [[ 0. 59.]]
#         else:  # if SLOPE > 72.5
#           if BF_Stock <= 43.80220031738281:
#             return [[0. 1.]]
#           else:  # if BF_Stock > 43.80220031738281
#             return [[2. 0.]]
#   else:  # if BF_QMD > 6.892452955245972
#     if BF_BA <= 3.3459471464157104:
#       if BF_Stock <= 5.31469988822937:
#         if SiteInd <= 64.0:
#           if OHost_Stock <= 0.4303354173898697:
#             if LAT <= 44.46719741821289:
#               return [[2. 0.]]
#             else:  # if LAT > 44.46719741821289
#               return [[0. 7.]]
#           else:  # if OHost_Stock > 0.4303354173898697
#             if OHost_BA <= 11.617401599884033:
#               if OHost_BA <= 1.6528891921043396:
#                 if LAT <= 44.95339393615723:
#                   return [[0. 5.]]
#                 else:  # if LAT > 44.95339393615723
#                   if SiteInd <= 53.5:
#                     return [[4. 0.]]
#                   else:  # if SiteInd > 53.5
#                     return [[0. 1.]]
#               else:  # if OHost_BA > 1.6528891921043396
#                 if NonHost_Stock <= 51.268449783325195:
#                   if ASPECT <= 350.5:
#                     if ELEV <= 1475.0:
#                       if OHost_Stock <= 3.638908267021179:
#                         if OHost_Stock <= 1.5837821960449219:
#                           if OHost_BA <= 11.356536865234375:
#                             return [[46.  0.]]
#                           else:  # if OHost_BA > 11.356536865234375
#                             if OHost_Stock <= 0.9950399398803711:
#                               return [[0. 1.]]
#                             else:  # if OHost_Stock > 0.9950399398803711
#                               return [[1. 0.]]
#                         else:  # if OHost_Stock > 1.5837821960449219
#                           if BF_BA <= 0.5704338550567627:
#                             return [[5. 0.]]
#                           else:  # if BF_BA > 0.5704338550567627
#                             return [[0. 2.]]
#                       else:  # if OHost_Stock > 3.638908267021179
#                         return [[0. 1.]]
#                     else:  # if ELEV > 1475.0
#                       if ELEV <= 1555.0:
#                         if SiteInd <= 56.0:
#                           return [[0. 3.]]
#                         else:  # if SiteInd > 56.0
#                           return [[1. 0.]]
#                       else:  # if ELEV > 1555.0
#                         if SiteInd <= 43.5:
#                           return [[13.  0.]]
#                         else:  # if SiteInd > 43.5
#                           if SLOPE <= 7.5:
#                             return [[6. 0.]]
#                           else:  # if SLOPE > 7.5
#                             if OHost_Stock <= 1.145631492137909:
#                               return [[0. 5.]]
#                             else:  # if OHost_Stock > 1.145631492137909
#                               return [[3. 0.]]
#                   else:  # if ASPECT > 350.5
#                     return [[0. 1.]]
#                 else:  # if NonHost_Stock > 51.268449783325195
#                   if OHost_Stock <= 2.1403121948242188:
#                     if BF_QMD <= 9.059625148773193:
#                       if NonHost_Stock <= 82.74165344238281:
#                         if BF_BA <= 1.278608500957489:
#                           if OHost_Stock <= 0.638521671295166:
#                             return [[0. 1.]]
#                           else:  # if OHost_Stock > 0.638521671295166
#                             if LAT <= 43.31287956237793:
#                               return [[0. 1.]]
#                             else:  # if LAT > 43.31287956237793
#                               return [[9. 0.]]
#                         else:  # if BF_BA > 1.278608500957489
#                           if ELEV <= 930.0:
#                             return [[0. 6.]]
#                           else:  # if ELEV > 930.0
#                             if OHost_Stock <= 0.7296458184719086:
#                               return [[5. 0.]]
#                             else:  # if OHost_Stock > 0.7296458184719086
#                               if OHost_Stock <= 1.0119603276252747:
#                                 return [[0. 5.]]
#                               else:  # if OHost_Stock > 1.0119603276252747
#                                 if BF_QMD <= 7.323338031768799:
#                                   return [[0. 2.]]
#                                 else:  # if BF_QMD > 7.323338031768799
#                                   return [[5. 0.]]
#                       else:  # if NonHost_Stock > 82.74165344238281
#                         return [[6. 0.]]
#                     else:  # if BF_QMD > 9.059625148773193
#                       return [[10.  0.]]
#                   else:  # if OHost_Stock > 2.1403121948242188
#                     return [[0. 3.]]
#             else:  # if OHost_BA > 11.617401599884033
#               if ELEV <= 1380.0:
#                 if SLOPE <= 0.5:
#                   if BF_BA <= 1.6109479665756226:
#                     return [[1. 0.]]
#                   else:  # if BF_BA > 1.6109479665756226
#                     return [[0. 4.]]
#                 else:  # if SLOPE > 0.5
#                   if BF_BA <= 0.9067547619342804:
#                     if SiteInd <= 53.0:
#                       return [[0. 2.]]
#                     else:  # if SiteInd > 53.0
#                       return [[1. 0.]]
#                   else:  # if BF_BA > 0.9067547619342804
#                     if LAT <= 45.56509971618652:
#                       return [[9. 0.]]
#                     else:  # if LAT > 45.56509971618652
#                       if OHost_BA <= 20.61991024017334:
#                         return [[0. 1.]]
#                       else:  # if OHost_BA > 20.61991024017334
#                         return [[1. 0.]]
#               else:  # if ELEV > 1380.0
#                 if BF_Stock <= 0.513700008392334:
#                   return [[1. 0.]]
#                 else:  # if BF_Stock > 0.513700008392334
#                   return [[0. 7.]]
#         else:  # if SiteInd > 64.0
#           if ELEV <= 1555.0:
#             return [[ 0. 10.]]
#           else:  # if ELEV > 1555.0
#             if BF_BA <= 0.9922734498977661:
#               return [[0. 1.]]
#             else:  # if BF_BA > 0.9922734498977661
#               return [[3. 0.]]
#       else:  # if BF_Stock > 5.31469988822937
#         if NonHost_Stock <= 55.233999252319336:
#           if OHost_Stock <= 0.7843758165836334:
#             return [[0. 6.]]
#           else:  # if OHost_Stock > 0.7843758165836334
#             if BF_Stock <= 9.946799755096436:
#               if OHost_BA <= 9.825899124145508:
#                 if SLOPE <= 1.25:
#                   if OHost_BA <= 9.175946235656738:
#                     if OHost_Stock <= 1.129859983921051:
#                       return [[0. 5.]]
#                     else:  # if OHost_Stock > 1.129859983921051
#                       if BF_Stock <= 7.880150079727173:
#                         return [[3. 0.]]
#                       else:  # if BF_Stock > 7.880150079727173
#                         return [[0. 1.]]
#                   else:  # if OHost_BA > 9.175946235656738
#                     return [[3. 0.]]
#                 else:  # if SLOPE > 1.25
#                   if OHost_BA <= 1.5730971693992615:
#                     return [[0. 1.]]
#                   else:  # if OHost_BA > 1.5730971693992615
#                     if ELEV <= 775.0:
#                       return [[0. 1.]]
#                     else:  # if ELEV > 775.0
#                       return [[19.  0.]]
#               else:  # if OHost_BA > 9.825899124145508
#                 if SiteInd <= 34.5:
#                   return [[4. 0.]]
#                 else:  # if SiteInd > 34.5
#                   if LAT <= 46.06216049194336:
#                     return [[0. 9.]]
#                   else:  # if LAT > 46.06216049194336
#                     if SLOPE <= 11.0:
#                       return [[2. 0.]]
#                     else:  # if SLOPE > 11.0
#                       return [[0. 1.]]
#             else:  # if BF_Stock > 9.946799755096436
#               if ELEV <= 490.0:
#                 return [[2. 0.]]
#               else:  # if ELEV > 490.0
#                 if BF_BA <= 3.1626110076904297:
#                   return [[ 0. 10.]]
#                 else:  # if BF_BA > 3.1626110076904297
#                   return [[1. 0.]]
#         else:  # if NonHost_Stock > 55.233999252319336
#           if OHost_BA <= 2.2537564039230347:
#             return [[3. 0.]]
#           else:  # if OHost_BA > 2.2537564039230347
#             if ASPECT <= 297.5:
#               if ELEV <= 280.0:
#                 if NonHost_Stock <= 94.1036491394043:
#                   return [[1. 0.]]
#                 else:  # if NonHost_Stock > 94.1036491394043
#                   return [[0. 1.]]
#               else:  # if ELEV > 280.0
#                 return [[ 0. 19.]]
#             else:  # if ASPECT > 297.5
#               if OHost_BA <= 5.509221792221069:
#                 return [[0. 1.]]
#               else:  # if OHost_BA > 5.509221792221069
#                 return [[1. 0.]]
#     else:  # if BF_BA > 3.3459471464157104
#       if BF_QMD <= 10.018383502960205:
#         if BF_QMD <= 7.5070319175720215:
#           if OHost_BA <= 30.135940551757812:
#             if LAT <= 43.270456314086914:
#               if ELEV <= 2015.0:
#                 return [[0. 3.]]
#               else:  # if ELEV > 2015.0
#                 return [[3. 0.]]
#             else:  # if LAT > 43.270456314086914
#               if ELEV <= 90.0:
#                 if SLOPE <= 9.5:
#                   return [[0. 4.]]
#                 else:  # if SLOPE > 9.5
#                   return [[3. 0.]]
#               else:  # if ELEV > 90.0
#                 if BF_QMD <= 6.93760085105896:
#                   if OHost_Stock <= 1.0597645044326782:
#                     if LAT <= 45.204444885253906:
#                       return [[ 0. 13.]]
#                     else:  # if LAT > 45.204444885253906
#                       if LAT <= 45.962646484375:
#                         return [[1. 0.]]
#                       else:  # if LAT > 45.962646484375
#                         return [[0. 1.]]
#                   else:  # if OHost_Stock > 1.0597645044326782
#                     if OHost_Stock <= 1.3759832978248596:
#                       return [[3. 0.]]
#                     else:  # if OHost_Stock > 1.3759832978248596
#                       if LAT <= 46.108619689941406:
#                         return [[0. 2.]]
#                       else:  # if LAT > 46.108619689941406
#                         return [[1. 0.]]
#                 else:  # if BF_QMD > 6.93760085105896
#                   if LAT <= 43.92099380493164:
#                     if NonHost_Stock <= 26.917299270629883:
#                       if NonHost_Stock <= 14.736649990081787:
#                         return [[0. 1.]]
#                       else:  # if NonHost_Stock > 14.736649990081787
#                         return [[2. 0.]]
#                     else:  # if NonHost_Stock > 26.917299270629883
#                       if SLOPE <= 2.75:
#                         if ELEV <= 1100.0:
#                           return [[1. 0.]]
#                         else:  # if ELEV > 1100.0
#                           return [[0. 1.]]
#                       else:  # if SLOPE > 2.75
#                         return [[ 0. 13.]]
#                   else:  # if LAT > 43.92099380493164
#                     if NonHost_Stock <= 10.18435001373291:
#                       if LAT <= 46.58410835266113:
#                         return [[0. 9.]]
#                       else:  # if LAT > 46.58410835266113
#                         if ELEV <= 1045.0:
#                           return [[2. 0.]]
#                         else:  # if ELEV > 1045.0
#                           return [[0. 1.]]
#                     else:  # if NonHost_Stock > 10.18435001373291
#                       if ELEV <= 1895.0:
#                         return [[ 0. 88.]]
#                       else:  # if ELEV > 1895.0
#                         if ELEV <= 1975.0:
#                           return [[1. 0.]]
#                         else:  # if ELEV > 1975.0
#                           return [[ 0. 20.]]
#           else:  # if OHost_BA > 30.135940551757812
#             return [[3. 0.]]
#         else:  # if BF_QMD > 7.5070319175720215
#           if SLOPE <= 10.5:
#             if ELEV <= 1645.0:
#               if NonHost_Stock <= 26.55389976501465:
#                 if SiteInd <= 55.0:
#                   if BF_Stock <= 5.2457499504089355:
#                     return [[0. 3.]]
#                   else:  # if BF_Stock > 5.2457499504089355
#                     if OHost_Stock <= 0.831124484539032:
#                       return [[0. 1.]]
#                     else:  # if OHost_Stock > 0.831124484539032
#                       if SiteInd <= 35.0:
#                         if ELEV <= 770.0:
#                           return [[0. 1.]]
#                         else:  # if ELEV > 770.0
#                           return [[1. 0.]]
#                       else:  # if SiteInd > 35.0
#                         return [[10.  0.]]
#                 else:  # if SiteInd > 55.0
#                   if BF_Stock <= 9.970600128173828:
#                     return [[1. 0.]]
#                   else:  # if BF_Stock > 9.970600128173828
#                     return [[0. 6.]]
#               else:  # if NonHost_Stock > 26.55389976501465
#                 if BF_QMD <= 8.531384944915771:
#                   if BF_QMD <= 7.52680230140686:
#                     return [[2. 0.]]
#                   else:  # if BF_QMD > 7.52680230140686
#                     if SiteInd <= 59.0:
#                       if SiteInd <= 30.5:
#                         if OHost_Stock <= 1.1517680883407593:
#                           return [[0. 1.]]
#                         else:  # if OHost_Stock > 1.1517680883407593
#                           return [[1. 0.]]
#                       else:  # if SiteInd > 30.5
#                         if OHost_Stock <= 0.9396654665470123:
#                           if OHost_Stock <= 0.922147125005722:
#                             if SiteInd <= 45.5:
#                               if SiteInd <= 43.0:
#                                 return [[0. 7.]]
#                               else:  # if SiteInd > 43.0
#                                 if OHost_BA <= 5.304042339324951:
#                                   return [[0. 1.]]
#                                 else:  # if OHost_BA > 5.304042339324951
#                                   return [[2. 0.]]
#                             else:  # if SiteInd > 45.5
#                               return [[ 0. 14.]]
#                           else:  # if OHost_Stock > 0.922147125005722
#                             return [[1. 0.]]
#                         else:  # if OHost_Stock > 0.9396654665470123
#                           return [[ 0. 31.]]
#                     else:  # if SiteInd > 59.0
#                       if BF_QMD <= 8.2528657913208:
#                         return [[0. 4.]]
#                       else:  # if BF_QMD > 8.2528657913208
#                         return [[2. 0.]]
#                 else:  # if BF_QMD > 8.531384944915771
#                   if LAT <= 46.18998146057129:
#                     if ELEV <= 250.0:
#                       return [[2. 0.]]
#                     else:  # if ELEV > 250.0
#                       if BF_Stock <= 2.0310999900102615:
#                         return [[1. 0.]]
#                       else:  # if BF_Stock > 2.0310999900102615
#                         if NonHost_Stock <= 84.86790084838867:
#                           if LAT <= 43.64997100830078:
#                             return [[1. 0.]]
#                           else:  # if LAT > 43.64997100830078
#                             return [[ 0. 15.]]
#                         else:  # if NonHost_Stock > 84.86790084838867
#                           return [[1. 0.]]
#                   else:  # if LAT > 46.18998146057129
#                     if OHost_BA <= 9.848533630371094:
#                       return [[6. 0.]]
#                     else:  # if OHost_BA > 9.848533630371094
#                       if SiteInd <= 34.5:
#                         return [[2. 0.]]
#                       else:  # if SiteInd > 34.5
#                         return [[0. 5.]]
#             else:  # if ELEV > 1645.0
#               if OHost_BA <= 6.547281742095947:
#                 return [[5. 0.]]
#               else:  # if OHost_BA > 6.547281742095947
#                 if BF_QMD <= 9.05504846572876:
#                   if SiteInd <= 35.5:
#                     if OHost_Stock <= 1.203822374343872:
#                       return [[5. 0.]]
#                     else:  # if OHost_Stock > 1.203822374343872
#                       return [[0. 1.]]
#                   else:  # if SiteInd > 35.5
#                     if ELEV <= 1740.0:
#                       if NonHost_Stock <= 3.1297500133514404:
#                         return [[0. 1.]]
#                       else:  # if NonHost_Stock > 3.1297500133514404
#                         return [[2. 0.]]
#                     else:  # if ELEV > 1740.0
#                       if BF_Stock <= 2.347450017929077:
#                         return [[1. 0.]]
#                       else:  # if BF_Stock > 2.347450017929077
#                         if LAT <= 45.3477783203125:
#                           return [[ 0. 12.]]
#                         else:  # if LAT > 45.3477783203125
#                           if BF_BA <= 6.793993234634399:
#                             return [[0. 2.]]
#                           else:  # if BF_BA > 6.793993234634399
#                             return [[1. 0.]]
#                 else:  # if BF_QMD > 9.05504846572876
#                   if OHost_Stock <= 0.868882954120636:
#                     return [[0. 1.]]
#                   else:  # if OHost_Stock > 0.868882954120636
#                     return [[6. 0.]]
#           else:  # if SLOPE > 10.5
#             if ELEV <= 3595.0:
#               if LAT <= 45.97120475769043:
#                 if OHost_Stock <= 1.501523494720459:
#                   if SiteInd <= 28.5:
#                     if BF_Stock <= 51.844200134277344:
#                       return [[1. 0.]]
#                     else:  # if BF_Stock > 51.844200134277344
#                       return [[0. 1.]]
#                   else:  # if SiteInd > 28.5
#                     if ASPECT <= 28.25:
#                       if NonHost_Stock <= 32.9903998374939:
#                         return [[1. 0.]]
#                       else:  # if NonHost_Stock > 32.9903998374939
#                         return [[0. 3.]]
#                     else:  # if ASPECT > 28.25
#                       if OHost_Stock <= 0.5550616681575775:
#                         if BF_QMD <= 7.738702058792114:
#                           return [[1. 0.]]
#                         else:  # if BF_QMD > 7.738702058792114
#                           return [[0. 4.]]
#                       else:  # if OHost_Stock > 0.5550616681575775
#                         return [[ 0. 58.]]
#                 else:  # if OHost_Stock > 1.501523494720459
#                   if OHost_Stock <= 1.7117742896080017:
#                     return [[3. 0.]]
#                   else:  # if OHost_Stock > 1.7117742896080017
#                     if BF_BA <= 10.793983936309814:
#                       return [[0. 6.]]
#                     else:  # if BF_BA > 10.793983936309814
#                       return [[1. 0.]]
#               else:  # if LAT > 45.97120475769043
#                 if SiteInd <= 49.0:
#                   return [[3. 0.]]
#                 else:  # if SiteInd > 49.0
#                   if BF_Stock <= 9.364300012588501:
#                     return [[0. 3.]]
#                   else:  # if BF_Stock > 9.364300012588501
#                     return [[1. 0.]]
#             else:  # if ELEV > 3595.0
#               return [[2. 0.]]
#       else:  # if BF_QMD > 10.018383502960205
#         if SiteInd <= 62.75:
#           if OHost_Stock <= 0.8875172138214111:
#             return [[0. 1.]]
#           else:  # if OHost_Stock > 0.8875172138214111
#             if BF_BA <= 5.79978346824646:
#               return [[13.  0.]]
#             else:  # if BF_BA > 5.79978346824646
#               if OHost_BA <= 11.22705888748169:
#                 if OHost_BA <= 7.299060821533203:
#                   if SiteInd <= 55.5:
#                     return [[4. 0.]]
#                   else:  # if SiteInd > 55.5
#                     return [[0. 1.]]
#                 else:  # if OHost_BA > 7.299060821533203
#                   return [[0. 3.]]
#               else:  # if OHost_BA > 11.22705888748169
#                 return [[4. 0.]]
#         else:  # if SiteInd > 62.75
#           return [[0. 2.]]

# %% [markdown]
# ## SVM

# %%
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier

# %%
clf = AdaBoostClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# /home/sean/anaconda3/envs/optimization/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 0.8372641509433962

# %%
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# /home/sean/anaconda3/envs/optimization/lib/python3.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 0.8514150943396226

# %%
import matplotlib.pyplot as plt
