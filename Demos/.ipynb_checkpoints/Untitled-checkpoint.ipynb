# %% [markdown]
# # EDA Initial Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('SBW_NetC_Outcomes_May42020.csv')

# %%
data.head()
# Out:
#    TimeStep LCA_Scenario                Stand_ID  Risk_Cat  \
# 0         0         NetC  0023200606030102900043         4
# 1         0     NetC_CHP  0023200606030102900043         4
# 2         0     NetC_WPS  0023200606030102900043         4
# 3        10         NetC  0023200606030102900043         4
# 4        10     NetC_CHP  0023200606030102900043         4
#
#            Time_Scenario  Heavy_Salvage  NoMgmt_Salvage  Moderate_Salvage  \
# 0       Time0_NetC (SUM)    -249.287884     -321.931519       -276.111511
# 1   Time0_NetC_CHP (SUM)    -252.148652     -323.713451       -278.458004
# 2   Time0_NetC_WPS (SUM)    -274.565938     -323.861210       -291.174651
# 3      Time10_NetC (SUM)    -340.727708     -409.369097       -362.934994
# 4  Time10_NetC_CHP (SUM)    -359.942747     -411.151029       -375.756065
#
#    Comm-Ind_Salvage  HighGrade_Salvage  Light_Salvage  Light_NoSalvage  \
# 0       -250.583375        -293.426896    -292.458908      -288.262585
# ...

# %% [markdown]
# ### Feature Descriptions
#
# * <b>LCA_Scenario</b>

# %%
data.describe()
# Out:
#            TimeStep      Risk_Cat  Heavy_Salvage  NoMgmt_Salvage  \
# count  73890.000000  73890.000000   73890.000000    73890.000000
# mean      20.000000      3.098051    -451.088741     -515.569317
# std       14.142231      1.074727     219.188918      267.286666
# min        0.000000      1.000000   -2886.123097    -3448.722333
# 25%       10.000000      2.000000    -546.071932     -617.066766
# 50%       20.000000      3.000000    -409.675872     -471.751795
# 75%       30.000000      4.000000    -306.193908     -350.081093
# max       40.000000      5.000000     -26.074071      -29.270915
#
#        Moderate_Salvage  Comm-Ind_Salvage  HighGrade_Salvage  Light_Salvage  \
# count      73890.000000      73890.000000       73890.000000   73890.000000
# mean        -468.573304       -462.567454        -504.076613    -490.204708
# std          225.897908        226.174692         257.063307     243.428310
# ...

# %%
sns.pairplot(data.drop(['TimeStep'], axis=1), hue='`')

# %% [markdown]
# Out of curiosity of how redundant the data is...

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
g = ['TimeStep', 'LCA_Scenario', 'Stand_ID', 'Time_Scenario']
X = data.drop(g, axis=1)
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

pca = PCA().fit(X)
np.cumsum(pca.explained_variance_) / np.sum(pca.explained_variance_)
# Out:
# array([0.86445985, 0.93765577, 0.96344168, 0.98098578, 0.98995199,
#        0.99563724, 0.99789877, 0.99921444, 0.99947185, 0.99969632,
#        0.99985311, 0.99992964, 0.99997639, 1.        ])
